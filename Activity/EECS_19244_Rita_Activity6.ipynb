# %% [markdown]
# #### Couple of Multiple Choice Questions (just warm up)

# %% [markdown]
# ### MCQ 1

# %% [markdown]
# Given what we've discussed in this course so far, if you wanted to store information about a date, how would you do so?
#
# - A) string
# - B) dictionary
# - C) list
# - D) integers stored in separate variables

# %%
#Type your answer here
B)Dictionary

# %% [markdown]
# ### MCQ 2
#
# Which of the following statements is true about the example we've been using?

# %%
class Dog():
    
    sound = 'Woof'
    
    def speak(self, n_times=2):
        return self.sound * n_times

# %% [markdown]
# - A) `Dog` is a Class, `sound` is an attribute, and `speak` is a method.
# - B) `Dog` is a function, `sound` is an attribute, and `speak` is a method.
# - C) `Dog` is a Class, `sound` is a method, and `speak` is an attribute.
# - D) `Dog` is a function, `sound` is an method, and `speak` is an attribute.

# %%
# Your answer here:
A)

# %% [markdown]
# ### This Notebook has got two parts.
# ### You may want to work on the Part I first, which is at the bottom of this page.
# ### Then come back to the Part II  in the top.

# %% [markdown]
# # Part II Problem Exercises

# %% [markdown]
# # Exercise: Creating Simple Objects
#
# Create Scoop class and three instances -- here, each instance is one scoop of ice cream
#
# You should be able to say the following:
#
# `s1 = Scoop('chocolate')`
#
# `s2 = Scoop('vanilla')`
#
# `s3 = Scoop('coffee')`

# %% [markdown]
# Once we are done with the above, then, when I say, `print(s1.flavor)` it should print `chocolate`

# %%
# YOUR CODE HERE
class Scoop():
  is_scoop = True
  def __init__(self, flavor):
    
    self.flavor = flavor

s1 = Scoop('chocolate')

s2 = Scoop('vanilla')

s3 = Scoop('coffee')

# %%
print(s1.flavor)
# Out:
# chocolate

# %% [markdown]
# Iterate over those flavors in a list and print their names
#
# It should print `chocolate, vanilla, coffee`

# %%
# YOUR CODE HERE
list1 = [s1,s2,s3]
for i in list1:
  print(i.flavor + ',')
# Out:
# chocolate,
# vanilla,
# coffee,

# %% [markdown]
# # Exercise: Visualize the code with pythontutor
#
# Copy the whole code from previous exercise, paste the code in www.pythontutor.com and observe line by line and write your understanding/comments, based on what you visualized.

# %% [markdown]
# ![dsp snip.PNG](data:image/png;base64,...)

# %% [markdown]
# The IDE on this particular website helps us understand the concepts of abstraction and encapsulation, two very integral parts of Object Oriented Programming. The Flowchart which is altered in every step of iteration because of a sequence shows the variable assignements, attributes and class instances for the very iteration in the execution command line. In this case instance of the scoop class is the 'flavor' which has various user defined attributes namely vanilla, chocolate and coffee.

# %% [markdown]
# # Exercise: Create a Bowl Class and methods in it
#
# From the previous exercise, we have three scoops. (you can cut and paste the previous exercise code)
#
# Now create a Bowl class.
#
# We can put scoops in the Bowl! (we are NOT inheriting anything here). A compositional relationship here.
#
# Scoop is a separate class and Bowl is a separate class.
#
#     b = Bowl()
#
# Hint: Within the Bowl class create an attribute with empty list `self.scoops = [ ]`.
#
# Hint: Create two methods, one for adding scoops (`add_scoops`), given that we may have variable number of scoops, you may want to use splat args (`*new_scoops`) in the `add_scoops` method. Then create another method `flavors` and return the added scoops
#
#     b.add_scoops(s1, s2)
#     b.add_scoops(s3)
#     b.flavors()  # returns a string of "chocolate, vanilla, coffee"

# %%
class Scoop():
  is_scoop = True
  def __init__(self, flavor):
    
    self.flavor = flavor

s1 = Scoop('chocolate')

s2 = Scoop('vanilla')

s3 = Scoop('coffee')

# %%
class Bowl():
  #
  def __init__(self, scoops=None):
    self.scoops=[]

    return None
    
    #return self.scoops
  def add_scoops(*new_scoops):
    self.add_scoops = new_scoops

  def flavors(self):
    return self.scoops

# %%
b = Bowl()
b.add_scoops(s1, s2)
b.add_scoops(s3)
b.flavors()  # returns a string of "chocolate, vanilla, coffee"
# Out:
# chocolate,
# vanilla,
# coffee,

# %% [markdown]
# # Exercise: Class Attribute
#
# Modify the Bowl class, such that adding a new scoop to the bowl will only work if you have fewer than 3 scoops.  In other words: max 3 scoops per bowl.
#
# Adding a new scoop to a bowl that is already full will be silently ignored.
#
# ##### Hint: You may want to use the following method in the Bowl class
#
#     def add_scoops(self, *new_scoops):
#
#         self.scoops += new_scoops[:self.max_scoops-len(self.scoops)]

# %%
# YOUR CODE HERE
class bowl():
  def __init__(self,scoops = []):
    return self.scoops
  def add_scoops(self, *new_scoops):

    self.scoops += new_scoops[:self.max_scoops-len(self.scoops)]
    if self.scoops>3:
      exit
    else:
      return self.scoops

# %% [markdown]
# # Exercise: Inheritance
# Take our existing Bowl class (for ice cream), and create a
#     subclass called BigBowl.  A BigBowl is just like a Bowl, except
#     that it has a maximum of 5 scoops, not 3.

# %%
# YOUR CODE HERE
class bigBowl(Bowl):
  def add_scoops(self, *new_scoops):

    self.scoops += new_scoops[:self.max_scoops-len(self.scoops)]
    if self.scoops>5:
      exit
    else:
      return self.scoops

# %% [markdown]
# # Part I Practice Exercises
#
# ### To make things easier, first work on the Practice Exercises given in the pdf file and enter them in cells below.

# %% [markdown]
# ### Exercise 1: Exploring Strings

# %%
my_str = 'hello World!'
type(my_str)
# Out:
# str

# %%
print(my_str.__doc__)
# Out:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to sys.getdefaultencoding().
# errors defaults to 'strict'.

# %%
my_str.__dir__()
# Out:
# ['__repr__',
#  '__hash__',
#  '__str__',
#  '__getattribute__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__iter__',
#  '__mod__',
#  '__rmod__',
#  '__len__',
#  '__getitem__',
#  '__add__',
#  '__mul__',
#  '__rmul__',
#  '__contains__',
#  '__new__',
#  'encode',
#  'replace',
#  'split',
#  'rsplit',
#  'join',
#  'capitalize',
#  'casefold',
#  'title',
#  'center',
#  'count',
#  'expandtabs',
#  'find',
#  'partition',
#  'index',
#  'ljust',
#  'lower',
#  'lstrip',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rstrip',
#  'rpartition',
#  'splitlines',
#  'strip',
#  'swapcase',
#  'translate',
#  'upper',
#  'startswith',
#  'endswith',
#  'isascii',
#  'islower',
#  'isupper',
#  'istitle',
#  'isspace',
#  'isdecimal',
#  'isdigit',
#  'isnumeric',
#  'isalpha',
#  'isalnum',
#  'isidentifier',
#  'isprintable',
#  'zfill',
#  'format',
#  'format_map',
#  '__format__',
#  'maketrans',
#  '__sizeof__',
#  '__getnewargs__',
#  '__doc__',
#  '__setattr__',
#  '__delattr__',
#  '__init__',
#  '__reduce_ex__',
#  '__reduce__',
#  '__subclasshook__',
#  '__init_subclass__',
#  '__dir__',
#  '__class__']

# %%
my_str.capitalize()
# Out:
# 'Hello world!'

# %%
my_str.upper()
# Out:
# 'HELLO WORLD!'

# %%
my_str.replace(' ', '')
# Out:
# 'helloWorld!'

# %% [markdown]
# ### Exercise 2: Creating a Pet Class

# %%
class Pet():
  """
  A class to capture useful
  information regarding my pets, just
  incase
  I lose track of them.
  """
  is_human = False
  owner = 'Michael Smith'

# %%
chubbles = Pet()

# %%
chubbles.is_human
# Out:
# False

# %%
chubbles.owner
print(chubbles.__doc__)
# Out:
#   A class to capture useful
#   information regarding my pets, just
#   incase
#   I lose track of them.

# %% [markdown]
# ### Exercise 3: Creating a Circle Class

# %%
class Circle():
  is_shape = True
  def __init__(self, radius, color):
    self.radius = radius
    self.color = color

# %%
first_circle = Circle(2, 'blue')
second_circle = Circle(3, 'red')

# %% [markdown]
# ### Exercise 4: The Country Class with Keyword Arguments

# %%
class Country():
  def __init__(self,
  name='Unspecified', population=None,
  size_kmsq=None):
    self.name = name
    self.population = population
    self.size_kmsq = size_kmsq

# %%
usa = Country(name='United States of America', size_kmsq=9.8e6)

# %%
usa.__dict__
# Out:
# {'name': 'United States of America',
#  'population': None,
#  'size_kmsq': 9800000.0}

# %% [markdown]
# ### Exercise 5: Adding an Instance Method to Our Pet Class

# %%
class Pet():
  def __init__(self, height):
    self.height = height
  is_human = False
  owner = 'Michael Smith'

# %%
class Pet():
  def __init__(self, height):
    self.height = height
  is_human = False
  owner = 'Michael Smith'

  def is_tall(self):
    return self.height >= 50

# %%
bowser = Pet(40)
bowser.is_tall()
# Out:
# False

# %%
bowser.height = 60
bowser.is_tall()
# Out:
# True

# %% [markdown]
# ### Exercise 5a: Adding Arguments to Instance Methods

# %%
class Pet():
  def __init__(self, height):
    self.height = height
    is_human = False
    owner = 'Michael Smith'

  def is_tall(self, tall_if_at_least):
    return self.height >= tall_if_at_least

# %%
bowser = Pet(40)

# %%
bowser.is_tall(30)
# Out:
# True

# %%
bowser.is_tall(50)
# Out:
# False

# %% [markdown]
# ### Exercise 6: Computing the Size of Our Country

# %%
class Country():
  def __init__(self,name='Unspecified', population=None, size_kmsq=None):
    self.name = name
    self.population = population
    self.size_kmsq = size_kmsq
  def size_miles_sq(self, conversion_rate=0.621371):
    return self.size_kmsq *conversion_rate ** 2

# %%
algeria = Country(name='Algeria',
size_kmsq=2.382e6)
algeria.size_miles_sq()
919694.772584862
# Out:
# 919694.772584862

# %%
algeria.size_miles_sq(conversion_rate=0.6)
# Out:
# 857520.0

# %% [markdown]
# ### Exercise 7: Adding an __str__ Method to the Country Class

# %%
class Country():
  def __init__(self, name='Unspecified', population=None, size_kmsq=None):
    self.name = name
    self.population = population
    self.size_kmsq = size_kmsq
  def __str__(self):
    return self.name

# %%
chad = Country(name='Chad')
print(chad)
# Out:
# Chad

# %%
def __str__(self):
  label = self.name
  if self.population:
    label = '%s, population: %s' % (label, self.population)
  if self.size_kmsq:
    label = '%s, size_kmsq: %s' % (label, self.size_kmsq)
    return label

# %%
chad = Country(name='Chad',
population=100)
print(chad)
# Out:
# Chad

# %% [markdown]
# ### Exercise 8: Inheriting from the Person Class

# %%
class Person():
  def __init__(self, first_name, last_name):
    self.first_name = first_name
    self.last_name = last_name

# %%
class Baby(Person):
  def speak(self):
    print('Blah blah blah')

# %%
class Adult(Person):
  def speak(self):
    print('Hello, my name is %s' % self.first_name)

# %%
jess = Baby('Jessie', 'Mcdonald')
tom = Adult('Thomas', 'Smith')
jess.speak()
tom.speak()
# Out:
# Blah blah blah
# Hello, my name is Thomas

# %%
class MyInt(int):
  def is_divisible_by(self, x):
    return self % x == 0

# %%
a = MyInt(8)
a.is_divisible_by(2)
# Out:
# True

# %% [markdown]
# ### Exercise 9: Sub-Classing the datetime.date Class

# %%
import datetime

# %%
class MyDate(datetime.date):
  def add_days(self, n):
    return self + datetime.timedelta(n)

# %%
d = MyDate(2019, 12, 1)
print(d.add_days(40))
print(d.add_days(400))
# Out:
# 2020-01-10
# 2021-01-04
